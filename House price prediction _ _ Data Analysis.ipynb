# %%
import kagglehub
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import kagglehub
#       2 import pandas as pd
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
from kagglehub import KaggleDatasetAdapter
# Download latest version
path = kagglehub.dataset_download("debayank2024/house-price-prediction")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\ASUS\.cache\kagglehub\datasets\debayank2024\house-price-prediction\versions\1

# %%
file = os.path.join(path, "modified_data.csv")

df = pd.read_csv(file)

# %%
df.head(10)
# Out:
#          date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  2014-05-02   313000.0       3.0       1.50         1340      7912     1.5
# 1  2014-05-02  2384000.0       5.0       2.50         3650      9050     2.0
# 2  2014-05-02   342000.0       3.0       2.00         1930     11947     1.0
# 3  2014-05-02   420000.0       3.0       2.25         2000      8030     1.0
# 4  2014-05-02   550000.0       4.0       2.50         1940     10500     1.0
# 5  2014-05-02   490000.0       2.0       1.00          880      6380     1.0
# 6  2014-05-02   335000.0       2.0       2.00         1350      2560     1.0
# 7  2014-05-02   482000.0       4.0       2.50         2710     35868     2.0
# 8  2014-05-02   452500.0       3.0       2.50         2430     88426     1.0
# 9  2014-05-02   640000.0       4.0       2.00         1520      6200     1.5
#
#    waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
# Number of columns and rows
df.shape
# Out:
# (4600, 18)

# %%
# --- Data Information ---
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            4600 non-null   str
#  1   price           4600 non-null   float64
#  2   bedrooms        4600 non-null   float64
#  3   bathrooms       4600 non-null   float64
#  4   sqft_living     4600 non-null   int64
#  5   sqft_lot        4600 non-null   int64
#  6   floors          4600 non-null   float64
#  7   waterfront      4600 non-null   int64
#  8   view            4600 non-null   int64
#  9   condition       4600 non-null   int64
#  10  sqft_above      4600 non-null   int64
#  11  sqft_basement   4600 non-null   int64
#  12  yr_built        4600 non-null   int64
#  13  yr_renovated    4600 non-null   int64
#  14  street          4600 non-null   str
#  15  city            4600 non-null   str
#  16  statezip        4600 non-null   str
# ...

# %%
# Data Description
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
# Check how many messing value
df.isnull().sum()
# Out:
# date              0
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view              0
# condition         0
# sqft_above        0
# sqft_basement     0
# yr_built          0
# yr_renovated      0
# street            0
# city              0
# statezip          0
# price_per_sqft    0
# dtype: int64

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#  ----Visualization----
fig, axs = plt.subplots(2,2, figsize = (19,10), sharey=True)

# flatten to from 2D array to 1D list of 4 elements
axes_flat = axs.flatten()

# using Zip to 
Columns_to_plot = ["bedrooms", "waterfront", "view", "condition"]


for i, ax in zip(Columns_to_plot, axes_flat): 
    percentage = df[i].value_counts(normalize=True) * 100
    bars = ax.bar(percentage.index, percentage.values, color="lightgreen", edgecolor="Black")

    ax.set_title(f"Distribution of houses by [{i}]".upper(), fontweight = 'bold', pad = 10)
    
    value = [f"{v:.2f}%" for v in bars.datavalues]
    ax.bar_label(bars, labels=value, padding=2)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #  ----Visualization----
# ----> 2 fig, axs = plt.subplots(2,2, figsize = (19,10), sharey=True)
#       4 # flatten to from 2D array to 1D list of 4 elements
#       5 axes_flat = axs.flatten()
#
# NameError: name 'plt' is not defined

# %%
df["floors"].value_counts()
# Out:
# floors
# 1.0    2174
# 2.0    1811
# 1.5     444
# 3.0     128
# 2.5      41
# 3.5       2
# Name: count, dtype: int64
